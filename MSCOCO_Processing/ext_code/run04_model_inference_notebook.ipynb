# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fcsvLog = 'test_keras_mode_v3.h5-log.csv'
tdataCSV = pd.read_csv(fcsvLog)
plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
# plt.plot(tdataCSV['epoch'], tdataCSV['loss'])
# plt.plot(tdataCSV['epoch'], tdataCSV['val_loss'])
plt.plot(tdataCSV['loss'])
plt.plot(tdataCSV['val_loss'])
plt.grid(True)
plt.legend(['loss-train', 'loss-val'], bbox_to_anchor=(1.05, 1), loc=2)
plt.subplot(2,1,2)
# plt.plot(tdataCSV['epoch'], tdataCSV['acc'])
# plt.plot(tdataCSV['epoch'], tdataCSV['val_acc'])
plt.plot(tdataCSV['acc'])
plt.plot(tdataCSV['val_acc'])
plt.grid(True)
plt.legend(['acc-train', 'acc-val'], bbox_to_anchor=(1.05, 1), loc=2)
